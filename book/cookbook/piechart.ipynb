# %% [markdown]
# # Making Pie Charts

# %% [markdown]
# Making Pie Charts is not as hard it seems. Matplotlib supports piecharts out of the box and Pandas provides a wrapper to plot one directly from a dataframe.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# We'll use the `un-min` dataset as example for plotting piechart.

# %%
df = pd.read_csv("../datasets/un-min.csv")

# %%
df.head()
# Out:
#        country   region  lifeMale  lifeFemale  infantMortality  GDPperCapita
# 0  Afghanistan     Asia      45.0        46.0              154          2848
# 1      Albania   Europe      68.0        74.0               32           863
# 2      Algeria   Africa      67.5        70.3               44          1531
# 3       Angola   Africa      44.9        48.1              124           355
# 4    Argentina  America      69.6        76.8               22          8055

# %% [markdown]
# ## Pie Chart with Pandas and Matplotlib

# %% [markdown]
# Let's try to plot the number of countries in each region as a pie chart.

# %%
df.region.value_counts()
# Out:
# Africa     53
# Asia       46
# Europe     40
# America    35
# Oceania    14
# Name: region, dtype: int64

# %%
counts = df.region.value_counts()

# %%
counts
# Out:
# Africa     53
# Asia       46
# Europe     40
# America    35
# Oceania    14
# Name: region, dtype: int64

# %%
counts.plot.pie()
# Out:
# <Axes: ylabel='region'>

# %% [markdown]
# To show the percentage values in each slice:

# %%
counts.plot.pie(autopct="%1.1f%%")
# Out:
# <Axes: ylabel='region'>

# %% [markdown]
# We can even highlight a slice. For example, the following snippet highlights the Asia.

# %%
counts
# Out:
# Africa     53
# Asia       46
# Europe     40
# America    35
# Oceania    14
# Name: region, dtype: int64

# %%
counts.plot.pie(autopct="%1.1f%%", explode=[0, 0.1, 0, 0, 0], shadow=True)
# Out:
# <Axes: ylabel='region'>

# %% [markdown]
# _Asia_ was the second entry in the data. We've told to explode the second one by 0.1 while keeping everything else in the original place. The `shadow=True` adds a bit of 3-d effect.

# %% [markdown]
# ## References
#
# * [pandas.DataFrame.plot.pie in Pandas API docs][1]
# * [Pie charts in Matplotlib docs][2]
#
# [1]: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.pie.html
# [2]: https://matplotlib.org/stable/gallery/pie_and_polar_charts/pie_features.html
